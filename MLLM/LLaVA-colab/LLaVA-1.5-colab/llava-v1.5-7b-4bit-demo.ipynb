# %%
# Install condacolab
# !pip install -q condacolab
import condacolab
condacolab.install()

# !conda create -n llava python=3.10 -y

# !source activate llava

# %%
# !git clone https://github.com/Czi24/LLaVA-20240713.git
# %cd /content/LLaVA-20240713/
# !pip install -e .

# %%
# !pip install huggingface_hub protobuf
from huggingface_hub import snapshot_download
snapshot_download(repo_id="liuhaotian/llava-v1.5-7b", local_dir="llava-v1.5-7b")

# %%
import threading
import subprocess

# start Controller
threading.Thread(
    target=lambda: subprocess.run(
        ['python3', '-m', 'llava.serve.controller', '--host', '0.0.0.0', '--port', '10000'],
        check=True
    ),
    daemon=True
).start()

# %%
import threading
import subprocess

# Define the command to run the model worker
command = [
    'python3', '-m', 'llava.serve.model_worker',
    '--host', '0.0.0.0',
    '--controller', 'http://localhost:10000',
    '--port', '40000',
    '--worker', 'http://localhost:40000',
    '--model-path', '/content/LLaVA-colab-20240713/llava-v1.5-7b',
    '--load-4bit'
]

# Run the command in a separate thread
thread = threading.Thread(
    target=lambda: subprocess.run(command, check=True, shell=False),
    daemon=True
)
thread.start()

# %%
# !python3 -m llava.serve.gradio_web_server --controller http://localhost:10000 --model-list-mode reload --share
# Out:
# 2024-07-12 18:08:17 | INFO | gradio_web_server | args: Namespace(host='0.0.0.0', port=None, controller_url='http://localhost:10000', concurrency_count=16, model_list_mode='reload', share=True, moderate=False, embed=False)
# 2024-07-12 18:08:17 | INFO | gradio_web_server | Models: []
# 2024-07-12 18:08:17 | INFO | gradio_web_server | Namespace(host='0.0.0.0', port=None, controller_url='http://localhost:10000', concurrency_count=16, model_list_mode='reload', share=True, moderate=False, embed=False)
# 2024-07-12 18:08:17 | ERROR | stderr | /usr/local/lib/python3.10/site-packages/gradio/components/dropdown.py:163: UserWarning: The value passed into gr.Dropdown() is not in the list of choices. Please update the list of choices to include:  or set allow_custom_value=True.
# 2024-07-12 18:08:17 | ERROR | stderr |   warnings.warn(
# 2024-07-12 18:08:17 | INFO | httpx | HTTP Request: GET https://checkip.amazonaws.com/ "HTTP/1.1 200 "
# 2024-07-12 18:08:17 | INFO | stdout | Running on local URL:  http://0.0.0.0:7860
# 2024-07-12 18:08:17 | INFO | httpx | HTTP Request: GET http://localhost:7860/startup-events "HTTP/1.1 200 OK"
# 2024-07-12 18:08:17 | INFO | httpx | HTTP Request: HEAD http://localhost:7860/ "HTTP/1.1 200 OK"
# 2024-07-12 18:08:17 | INFO | httpx | HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 2024-07-12 18:08:17 | INFO | stdout | IMPORTANT: You are using gradio version 4.16.0, however version 4.29.0 is available, please upgrade.
# 2024-07-12 18:08:17 | INFO | stdout | --------
# 2024-07-12 18:08:17 | INFO | httpx | HTTP Request: GET https://api.gradio.app/v2/tunnel-request "HTTP/1.1 200 OK"
# 2024-07-12 18:08:18 | INFO | httpx | HTTP Request: POST https://api.gradio.app/gradio-initiated-analytics/ "HTTP/1.1 200 OK"
# 2024-07-12 18:08:18 | INFO | stdout | Running on public URL: https://85b148bfb80205fec5.gradio.live
# 2024-07-12 18:08:18 | INFO | stdout |
# 2024-07-12 18:08:18 | INFO | stdout | This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 2024-07-12 18:08:18 | INFO | httpx | HTTP Request: POST https://api.gradio.app/gradio-launched-telemetry/ "HTTP/1.1 200 OK"
# 2024-07-12 18:08:50 | INFO | gradio_web_server | load_demo. ip: 172.31.5.73
# 2024-07-12 18:08:50 | INFO | gradio_web_server | Models: ['llava-v1.5-7b']
# 2024-07-12 18:08:50 | ERROR | stderr | Traceback (most recent call last):
# 2024-07-12 18:08:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/site-packages/gradio/routes.py", line 569, in predict
# 2024-07-12 18:08:50 | ERROR | stderr |     output = await route_utils.call_process_api(
# 2024-07-12 18:08:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/site-packages/gradio/route_utils.py", line 231, in call_process_api
# 2024-07-12 18:08:50 | ERROR | stderr |     with utils.MatplotlibBackendMananger():
# 2024-07-12 18:08:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/site-packages/gradio/utils.py", line 888, in __exit__
# 2024-07-12 18:08:50 | ERROR | stderr |     matplotlib.use(self._original_backend)
# 2024-07-12 18:08:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/site-packages/matplotlib/__init__.py", line 1255, in use
# 2024-07-12 18:08:50 | ERROR | stderr |     plt.switch_backend(name)
# 2024-07-12 18:08:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/site-packages/matplotlib/pyplot.py", line 415, in switch_backend
# 2024-07-12 18:08:50 | ERROR | stderr |     module = backend_registry.load_backend_module(newbackend)
# 2024-07-12 18:08:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/site-packages/matplotlib/backends/registry.py", line 323, in load_backend_module
# 2024-07-12 18:08:50 | ERROR | stderr |     return importlib.import_module(module_name)
# 2024-07-12 18:08:50 | ERROR | stderr |   File "/usr/local/lib/python3.10/importlib/__init__.py", line 126, in import_module
# 2024-07-12 18:08:50 | ERROR | stderr |     return _bootstrap._gcd_import(name[level:], package, level)
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 992, in _find_and_load_unlocked
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
# 2024-07-12 18:08:50 | ERROR | stderr |   File "<frozen importlib._bootstrap>", line 1004, in _find_and_load_unlocked
# 2024-07-12 18:08:50 | ERROR | stderr | ModuleNotFoundError: No module named 'ipykernel'
# 2024-07-12 18:08:55 | INFO | gradio_web_server | load_demo. ip: 172.31.5.73
# 2024-07-12 18:08:55 | INFO | gradio_web_server | Models: ['llava-v1.5-7b']
# 2024-07-12 18:09:00 | INFO | gradio_web_server | add_text. ip: 172.31.5.73. len: 33
# 2024-07-12 18:09:01 | INFO | gradio_web_server | http_bot. ip: 172.31.5.73
# 2024-07-12 18:09:01 | INFO | gradio_web_server | model_name: llava-v1.5-7b, worker_addr: http://localhost:40000
# 2024-07-12 18:09:01 | INFO | gradio_web_server | ==== request ====
# {'model': 'llava-v1.5-7b', 'prompt': "A chat between a curious human and an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the human's questions. USER: \nWhat is unusual about this image? ASSISTANT:", 'temperature': 0.2, 'top_p': 0.7, 'max_new_tokens': 512, 'stop': '</s>', 'images': "List of 1 images: ['b939abf2c4553ce07e642170aee3a3d7']"}
# 2024-07-12 18:09:24 | INFO | gradio_web_server | The unusual aspect of this image is that a man is standing on a folding table, which is attached to the back of a yellow taxi. This is not a common sight, as people typically do not stand on folding tables while riding in a vehicle. The man is also holding a blue shirt, which adds to the unconventional nature of the scene. The presence of a traffic light in the background further emphasizes that this is taking place in an urban environment, where such an unusual situation would be more likely to occur.
